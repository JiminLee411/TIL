# %%
# 뒷 부분에 활용할 패키지를 미리 import 합시다.
from IPython.display import IFrame

# %% [markdown]
# # 문자열 메소드 활용하기

# %% [markdown]
# ## 변형
#
# ### `.capitalize()`, `title()`, `.upper()`
#
# `.capitalize()` : 앞글자를 대문자로 만들어 반환합니다.
#
# `.title()` : 어포스트로피나 공백을 이후를 대문자로 만들어 반환합니다.
#
# `.upper()` : 모두 대문자로 만들어 반환합니다.

# %%
a = "hI! Everyone, I'm kim"
# 아래에 코드를 작성하세요.
print(a.capitalize()) # 맨앞글자만 대문자
print(a.title()) # 공백이후 맨 앞글자 대문자로
print(a.upper()) # 다 대문자로
# Out:
# Hi! everyone, i'm kim
# Hi! Everyone, I'M Kim
# HI! EVERYONE, I'M KIM

# %% [markdown]
# ### `lower()`, `swapcase()`
#
# `lower()` : 모두 소문자로 만들어 반환합니다.
#
# `swapcase()` : 대<->소문자로 변경하여 반환합니다.

# %%
a = "hI! Everyone, I'm kim"
# 아래에 코드를 작성하세요.
print(a.swapcase()) # 대소문자를 바꿈
# Out:
# Hi! eVERYONE, i'M KIM

# %% [markdown]
# ### `.join(iterable)`
#
# 특정한 문자열로 만들어 반환합니다.
#
# iterable : 순차적으로값을꺼내올 수 있는 것

# %%
# 아래에 코드를 작성하세요.
print('apple'.join(['1','2','3','4']))
# Out:
# 1apple2apple3apple4

# %% [markdown]
# ### `.replace(old, new[, count])`
#
# 바꿀 대상 글자를 새로운 글자로 바꿔서 반환합니다.
#
# count를 지정하면 해당 갯수만큼만 시행합니다.

# %%
# 아래에 코드를 작성하세요.
'apple'.replace('p', 'a') # 모든 p를 a로 변경
# Out:
# 'aaale'

# %%
'apple'.replace('p', 'a', 1) # 하나의 p를 a로 변경
# Out:
# 'aaple'

# %% [markdown]
# ### 글씨 제거 (`strip([chars])`)
#
# 특정한 문자들을 지정하면,  양쪽을 제거하거나 왼쪽을 제거하거나(lstrip) 오른쪽을 제거합니다(rstrip)
#
# 지정하지 않으면 공백을 제거합니다.

# %%
# 아래에 코드를 작성하세요.
'                     hi'.strip() # 공백을 지위줌
# Out:
# 'hi'

# %%
'        hi          '.strip() # 양쪽으로 지워줌
# Out:
# 'hi'

# %%
'       hi          '.rstrip() # 오른쪽만 지워줌
# Out:
# '       hi'

# %%
'       hi          '.lstrip() # 왼쪽만 지워줌
# Out:
# 'hi          '

# %%
'안녕하세요^^'.strip('^^') # 문자도 지워줌
# Out:
# '안녕하세요'

# %%
'aabbaabbaa'.strip('aa') # 문자열의 끝쪽만 지워줌, 중간은 못지움
# Out:
# 'bbaabb'

# %% [markdown]
# ## 탐색 및 검증
#
# ### `.find(x)` : x의 첫 번째 위치를 반환합니다. 없으면, -1을 반환합니다.

# %%
# 아래에 코드를 작성하세요.
'wow!'.find('w') # 찾는 문자의 첫번째 위치를 반환
# Out:
# 0

# %%
'wow!'.find('a') # 없으면 -1 반환
# Out:
# -1

# %%
'wow!'.find('o')
# Out:
# 1

# %% [markdown]
# ### `.index(x)` : x의 첫번째 위치를 반환합니다. 없으면, 오류가 발생합니다.

# %%
# 아래에 코드를 작성하세요.
'wow!'.index('w')
# Out:
# 0

# %%
'wow!'.index('a') # 없으면 오류 반환
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-b0bddad0e7b3> in <module>
# ----> 1 'wow!'.index('a')
#
# ValueError: substring not found

# %% [markdown]
# ## `split()`
#
# 문자열을 특정한 단위로 나누어 리스트로 반환합니다.

# %%
# 아래에 코드를 작성하세요.
'3 10'.split()
# Out:
# ['3', '10']

# %%
'apple'.split('p')
# Out:
# ['a', '', 'le']

# %%
'a_b_c'.split('_')
# Out:
# ['a', 'b', 'c']

# %%
inputs = '3 10'
a, b = map(int, inputs.split())
print(a, b)
# Out:
# 3 10

# %% [markdown]
# ### 다양한 확인 메소드 : 참/거짓 반환
# ```
# .isalpha(), .isdecimal(), .isdigit(), .isnumeric(), .isspace(), .isuper(), .istitle(), .islower()
# ```
#
# ```python
# dir('string')
# ```
#
# decimal -> digit -> numeric 이렇게 포함됨
#
#
# |isdecimal()|isdigit()|isnumeric()|Example|
# |:----------:|:----------:|:----------:|:-----------------------:|
# |True|True|True|"038", "੦੩੮", "０３８"|
# |False|True|True|"⁰³⁸", "🄀⒊⒏", "⓪③⑧"|
# |False|False|True|"↉⅛⅘", "ⅠⅢⅧ", "⑩⑬㊿", "壹貳參"|
# |False|False|False|"abc", "38.0", "-38"|

# %%
'a'.isalpha()
# Out:
# True

# %%
'안'.isalpha()
# Out:
# True

# %%
'0111'.isnumeric()
# Out:
# True

# %%
'1'.isnumeric()
# Out:
# True

# %%
'0111'.isdigit()
# Out:
# True

# %%
dir('asdf')
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %% [markdown]
# # 리스트 메소드 활용하기
#
# ## 값 추가 및 삭제
#
# ### `.append(x)`
#
# 리스트에 값을 추가할 수 있습니다.

# %%
# 카페 리스트를 만들어봅시다.
caffe = ['starbucks', 'tomntoms', 'hollys']
print(caffe)
# Out:
# ['starbucks', 'tomntoms', 'hollys']

# %%
# 값을 추가해봅시다.
caffe.append('삼성화재연수원 카페')

# %%
# 어렵게 넣어보도록 해봅시다.
caffe[len(caffe):] = ['ediya']
print(caffe)
# Out:
# ['starbucks', 'tomntoms', 'hollys', '삼성화재연수원 카페', 'ediya']

# %%
caffe[len(caffe):]
# Out:
# []

# %% [markdown]
# ### `.extend(iterable)`
#
# 리스트에 iterable(list, range, tuple, string*유의*) 값을 붙일 수가 있습니다.

# %%
# 앞서 만든 리스트에 추가해봅시다.
caffe.extend(['카페베네'])
print(caffe)
# Out:
# ['starbucks', 'tomntoms', 'hollys', '삼성화재연수원 카페', 'ediya', '카페베네']

# %%
# 앞서 배운 list concatenate와 동일합니다.
caffe.extend(('빽다방', '설빙'))
print(caffe)
# Out:
# ['starbucks', 'tomntoms', 'hollys', '삼성화재연수원 카페', 'ediya', '카페베네', '빽다방', '설빙']

# %%
# 앞서 배운 list concatenate와 동일합니다.
caffe = caffe + ['드롭탑']
print(caffe)
# Out:
# ['starbucks', 'tomntoms', 'hollys', '삼성화재연수원 카페', 'ediya', '카페베네', '빽다방', '설빙', '드롭탑']

# %%
# append와 비교해봅시다.
caffe.append(['동네카페'])
print(caffe)
# Out:
# ['starbucks', 'tomntoms', 'hollys', '삼성화재연수원 카페', 'ediya', '카페베네', '빽다방', '설빙', '드롭탑', ['동네카페']]

# %%
caffe.extend(['커피그루나루'])
print(caffe)
# Out:
# ['starbucks', 'tomntoms', 'hollys', '삼성화재연수원 카페', 'ediya', '카페베네', '빽다방', '설빙', '커', '피', '그', '루', '나', '루', '커', '피', '그', '루', '나', '루', '커피그루나루']

# %%
a = '안녕하세요, 여러분'
a.split()
# Out:
# ['안녕하세요,', '여러분']

# %%
b = '안녕하세요, 여러분'
result = []
result.extend(b)
result
# Out:
# ['안', '녕', '하', '세', '요', ',', ' ', '여', '러', '분']

# %% [markdown]
# ### `insert(i, x)`
#
# 정해진 위치 `i`에 값을 추가합니다.

# %%
# 앞서 만든 리스트의 가장 앞에 'hi'를 넣어봅시다.
caffe.insert(0, 'hi')

# %%
print(caffe)
# Out:
# ['hi', 'starbucks', 'tomntoms', 'hollys', '삼성화재연수원 카페', 'ediya', '카페베네', '빽다방', '설빙', '드롭탑', ['동네카페'], ['동네카페'], '커', '피', '그', '루', '나', '루']

# %%
# 앞서 만든 리스트의 가장 뒤에 'bye'를 넣어봅시다
caffe.insert(-1, 'bye')

# %%
print(caffe) # 마지막에 안들어감
# Out:
# ['hi', 'starbucks', 'tomntoms', 'hollys', '삼성화재연수원 카페', 'ediya', '카페베네', '빽다방', '설빙', '드롭탑', ['동네카페'], '커', '피', '그', '루', '나', 'bye', '루']

# %%
caffe.insert(len(caffe), 'bye')

# %%
print(caffe)
# Out:
# ['hi', 'starbucks', 'tomntoms', 'hollys', '삼성화재연수원 카페', 'ediya', '카페베네', '빽다방', '설빙', '드롭탑', ['동네카페'], '커', '피', '그', '루', '나', 'bye', 'bye', '루', 'bye']

# %%
# 길이를 넘어서는 인덱스는 무조건 마지막에 하나만 붙습니다.
caffe.insert(len(caffe)+1000, '안녕')
print(caffe)
# Out:
# ['hi', 'starbucks', 'tomntoms', 'hollys', '삼성화재연수원 카페', 'ediya', '카페베네', '빽다방', '설빙', '드롭탑', ['동네카페'], '커', '피', '그', '루', '나', 'bye', 'bye', '루', 'bye', '안녕']

# %% [markdown]
# ### `remove(x)`
#
# 리스트에서 값이 x인 것을 삭제합니다.

# %%
# remove를 사용해봅시다.
numbers = [1, 2, 3, 1, 2]
print(numbers)
# Out:
# [1, 2, 3, 1, 2]

# %%
# 중복된 값 1을 삭제 해봅시다.
numbers.remove(1)

# %%
print(numbers)
# Out:
# [2, 3, 1, 2]

# %%
# 한번 더 삭제해봅시다.
numbers.remove(1)
print(numbers)
# Out:
# [2, 3, 2]

# %%
# remove는 값이 없으면 오류가 발생합니다. 확인해봅시다.
numbers.remove(1)
print(numbers)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-3c002b34729b> in <module>
#       1 # remove는 값이 없으면 오류가 발생합니다. 확인해봅시다.
# ----> 2 numbers.remove(1)
#       3 print(numbers)
#
# ValueError: list.remove(x): x not in list

# %% [markdown]
# ### `.pop(i)`
#
# 정해진 위치 `i`에 있는 값을 삭제하며, 그 항목을 반환합니다.
#
# `i`가 지정되지 않으면 마지막 항목을 삭제하고 되돌려줍니다.

# %%
# pop을 사용해봅시다.
a = [1, 2, 3, 4, 5, 6]

# %%
# 가장 앞에 있는 것을 삭제해봅시다. return도 확인해보세요.
a.pop(0)
# Out:
# 1

# %%
a
# Out:
# [2, 3, 4, 5, 6]

# %%
# 값이 return이 된다는 것은 별도의 변수에 저장할 수 있다는 것입니다. 
member = ['연용흠', '박태수', '염동환', '토마스']

# %%
bye_member = member.pop() # 아무값도 안넣으면 가장 마지막 원소 pop

# %%
print(f'{bye_member}님 이용해주셔서 감사합니다.')
# Out:
# 토마스님 이용해주셔서 감사합니다.

# %% [markdown]
# ## 탐색 및 정렬

# %% [markdown]
# ### `.index(x)`
#
# 원하는 값을 찾아 index 값을 반환합니다.

# %%
# index를 사용해봅시다.
a = [1, 2, 3, 4, 5]

# %%
# index는 없을 시 오류가 발생합니다. 확인해봅시다. 
# 앞서 remove 역시도 같은 에러가 발생하였습니다. (ValueError)
a.index(3)
# Out:
# 2

# %%
a.index(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-105-be2bb036fbfd> in <module>
# ----> 1 a.index(10)
#
# ValueError: 10 is not in list

# %% [markdown]
# ### `.count(x)`
#
# 원하는 값의 갯수를 확인할 수 있습니다.

# %%
# count를 사용해봅시다.
a = [1, 2, 5, 1, 5, 1]
a.count(1)
# Out:
# 3

# %%
# 따라서 원하는 값을 모두 삭제하려면 다음과 같이 할 수 있습니다.
for _ in range(a.count(1)): # `_` : i라는 변수를 내부에서 사용안할시 굳이 메모리에 저장하지 않는 방법.
    a.remove(1)
print(a)
# Out:
# [2, 5, 5]

# %%
# 모두 삭제되었는지 검증해봅시다.
1 in a
# Out:
# False

# %% [markdown]
# ### `.sort()`
#
# 정렬을 합니다.
#
# sorted()와는 다르게 원본 list를 변형시키고, None을 리턴합니다.

# %%
import random
lotto = random.sample(range(1, 46), 6)
print(lotto)
# Out:
# [31, 25, 5, 4, 15, 24]

# %%
# sort를 사용해봅시다.
lotto.sort()
print(lotto)
# Out:
# [4, 5, 15, 24, 25, 31]

# %%
# sort는 반환값이 None이고 원본 자체를 바꾸기 때문에, 아래처럼 작성하면 안된다ㅣ
lotto = lotto.sort()
print(lotto)
# Out:
# None

# %%
# sorted()는 원본은 바꾸지 않지만, 정렬된 결과를 반환한다. 따라서 아래처럼 작성하면 안된다.
a = [1, 5, 3]
sorted(a)
print(a)
# Out:
# [1, 5, 3]

# %% [markdown]
# ### `.reverse()`
#
# 반대로 뒤집습니다. (정렬 아님)

# %%
classroom = ['Tom', 'David', 'Justin']
print(classroom)
# Out:
# ['Tom', 'David', 'Justin']

# %%
classroom.reverse()

# %%
print(classroom)
# Out:
# ['Justin', 'David', 'Tom']

# %% [markdown]
# ## 복사

# %%
# 리스트 복사를 해봅시다.
original_list = [1, 2, 3]
copied_list = original_list
print(copied_list)
# Out:
# [1, 2, 3]

# %%
# 복사한 리스트의 첫번째 원소의 값을 바꾸고 리스트들을 출력해봅시다.
copied_list[0] = '연용흠'

# %%
copied_list
# Out:
# ['연용흠', 2, 3]

# %%
original_list
# Out:
# ['연용흠', 2, 3]

# %%
# id 값을 확안해봅시다.
print(id(original_list), id(copied_list))
# Out:
# 91968456 91968456

# %%
# 숫자를 확인해봅시다.
a = 3
b = a
b = 5
print(a,b)
# Out:
# 3 5

# %%
# 딕셔너리도 확인해봅시다.
a = {'apple': '사과', 'banana': '바나나'}
b = a
b['apple'] = '맥북'
print(a, b)
# Out:
# {'apple': '맥북', 'banana': '바나나'} {'apple': '맥북', 'banana': '바나나'}

# %% [markdown]
# ### copy
# > pythontutor를 활용하여 자세하게 알아봅시다.
#
# * 파이썬에서 모든 변수는 객체의 주소를 가지고 있을 뿐입니다.
#
# ```
# num = [1, 2, 3]
# ```
#
# * 위와 같이 변수를 생성하면 hong이라는 객체를 생성하고, 변수에는 객체의 주소가 저장됩니다.
#
# * 변경가능한(mutable) 자료형과 변경불가능한(immutable) 자료형은 서로 다르게 동작합니다.
#
# 따라서, 복사를 하고 싶을 때에는 다음과 같이 해야한다.

# %%
# mutable - 리스트
IFrame('https://goo.gl/vx1yGx', width='100%', height='300px')
# Out:
#         <iframe
#             width="100%"
#             height="300px"
#             src="https://goo.gl/vx1yGx"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# immutable - integer
IFrame('https://goo.gl/N43pw6', width='100%', height='300px')
# Out:
#         <iframe
#             width="100%"
#             height="300px"
#             src="https://goo.gl/N43pw6"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# 리스트를 복사해봅시다.
a = [1, 2, 3]
b = list(a)
b[0] = 5
print(a, b)
# Out:
# [1, 2, 3] [5, 2, 3]

# %%
# 다른 방법으로 복사해봅시다.
# a의 주소를 복사한것이 아니라 a를 슬라이싱한 결과를 b에 반환한것
a = [1, 2, [2, 3]]
b = a[:]
b[2][0] = 5
print(a, b)
# Out:
# [1, 2, [5, 3]] [1, 2, [5, 3]]

# %%
a = [1, 2, 3]
b = a[:]
b = [3, 2, 3]
print(a, b)
# Out:
# [1, 2, 3] [3, 2, 3]

# %%
# 얇은 복사 예시
IFrame('https://goo.gl/ZH6yZd', width='100%', height='300px')

# %% [markdown]
# * 하지만, 이렇게 하는 것도 일부 상황에만 서로 다른 얕은 복사(shallow copy)입니다.

# %%
# 2차원 리스트를 복사해봅시다.
a = [1, 2, [1, 2]]
b = a[:]
b[2][0] = 3
print(a, b)
# 이 상황은 b[2][0]의 주소로 가서 값을 직접 바꾼것이기 때문에 딥카피가 필요하다.
# Out:
# [1, 2, [3, 2]] [1, 2, [3, 2]]

# %%
a = [1, 2, [1, 2]]
b = a[::-1]
b[0][0] = 3
print(a, b)
# Out:
# [1, 2, [3, 2]] [[3, 2], 2, 1]

# %%
a = [1, 2, [1, 2]]
b = a[:]
b[2] = 1
print(a, b)
# 이 상황은 .b[2]에 새로운 주소를 저장하는것이므로 영향이 안끼친다.
# Out:
# [1, 2, [1, 2]] [1, 2, 1]

# %%
# 얇은 복사 - 2차원 리스트
IFrame('https://goo.gl/FZcYbJ', width='100%', height='300px')
# Out:
#         <iframe
#             width="100%"
#             height="300px"
#             src="https://goo.gl/FZcYbJ"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# * 만일 중첩된 상황에서 복사를 하고 싶다면, 깊은 복사(deep copy)를 해야합니다.
#
# * 즉, 내부에 있는 모든 객체까지 새롭게 값이 변경됩니다.

# %%
# 깊은 복사를 사용해봅시다.
import copy
a = [1, 3, [1, 2]]
b = copy.deepcopy(a)
b[2][0] = 3
print(a, b)
# Out:
# [1, 3, [1, 2]] [1, 3, [3, 2]]

# %%
# 깊은 복사
IFrame('https://goo.gl/dtnCzY', width='100%', height='300px')
# Out:
#         <iframe
#             width="100%"
#             height="300px"
#             src="https://goo.gl/dtnCzY"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
map(int, [1, 2])

# %% [markdown]
# ## `.clear()`
#
# 리스트의 모든 항목을 삭제합니다.

# %%
# clear를 사용해봅시다.
a = [1, 2, 3]
a.clear()
print(a)
# Out:
# []

# %% [markdown]
# # List Comprehension
#
# List를 만들 수 있는 간단한 방법이 있습니다.

# %% [markdown]
# ### 세제곱리스트
#
# > 다음의 리스트를 만들어보세요.
#
# - 1~10까지의 숫자로 만든 세제곱 담긴 리스트 `cubic_list`

# %%
numbers = range(1,11)

# %%
# 기존의방법
cubic_list = []
for num in numbers:
    cubic_list.append(num**3)
print(cubic_list)
# Out:
# [1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]

# %%
# List Comprehension
cubic_list2 = [num**3 for num in numbers]
print(cubic_list2)
# Out:
# [1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]

# %% [markdown]
# ### 짝수리스트
# > 다음의 리스트를 만들어보세요.
#
# - 1~10까지의 숫자중 짝수만 담긴 리스트 `even_list`
# - 여러개의 `for` 혹은 `if`문을 중첩적으로 사용 가능합니다.

# %%
numbers = range(1,11)

# %%
# 기존의방법
even_list = []
for num in numbers:
    if not num % 2:
        even_list.append(num)
print(even_list)
# Out:
# [2, 4, 6, 8, 10]

# %%
# List Comprehension
even_list2 = [num for num in numbers if not num % 2]
print(even_list2)
# Out:
# [2, 4, 6, 8, 10]

# %% [markdown]
# ### 곱집합
#
# > 주어진 두 list의 가능한 모든 조합을 담은 `pair` 리스트를 만들어주세요.
#
# 1. 반복문 활용
# 2. list comprehension 활용
#
# ---
#
# ```
# girls = ['jane', 'iu', 'mary']
# boys = ['justin', 'david', 'kim']
#
# 예시 출력)
#
# [('justin', 'jane'), ('justin', 'iu'), ('justin', 'mary'), ('david', 'jane'), ('david', 'iu'), ('david', 'mary'), ('kim', 'jane'), ('kim', 'iu'), ('kim', 'mary')]
# ```

# %%
girls = ['jane', 'iu', 'mary']
boys = ['justin', 'david', 'kim']

# %%
# 반복문을 활용하여 만들어주세요.
res = []
for i in girls:
    for j in boys:
        res.append((i,j))
print(res)
# Out:
# [('jane', 'justin'), ('jane', 'david'), ('jane', 'kim'), ('iu', 'justin'), ('iu', 'david'), ('iu', 'kim'), ('mary', 'justin'), ('mary', 'david'), ('mary', 'kim')]

# %%
# List comprehension을 활용하여 만들어주세요.
[(girl, boy) for girl in girls for boy in boys]
# Out:
# [('jane', 'justin'),
#  ('jane', 'david'),
#  ('jane', 'kim'),
#  ('iu', 'justin'),
#  ('iu', 'david'),
#  ('iu', 'kim'),
#  ('mary', 'justin'),
#  ('mary', 'david'),
#  ('mary', 'kim')]

# %% [markdown]
# ### 피타고라스 정리
#
# > 주어진 조건(x < y < z < 50) 내에서 피타고라스 방정식의 해를 찾아보세요.
#
# 1. 반복문 활용
#
# 2. list comprehension 활용
#
# ```
# 예시 출력)
# [(3, 4, 5), (5, 12, 13), (6, 8, 10), (7, 24, 25), (8, 15, 17), (9, 12, 15), (9, 40, 41), (10, 24, 26), (12, 16, 20), (12, 35, 37), (15, 20, 25), (15, 36, 39), (16, 30, 34), (18, 24, 30), (20, 21, 29), (21, 28, 35), (24, 32, 40), (27, 36, 45)]
# ```

# %%
# 반복문을 활용하여 만들어주세요.
res = []
for x in range(1, 50):
    for y in range(x+1, 50):
        for z in range(y+1, 50):
            if x**2 + y**2 == z**2:
                res.append((x,y,z))
print(res)
# Out:
# [(3, 4, 5), (5, 12, 13), (6, 8, 10), (7, 24, 25), (8, 15, 17), (9, 12, 15), (9, 40, 41), (10, 24, 26), (12, 16, 20), (12, 35, 37), (15, 20, 25), (15, 36, 39), (16, 30, 34), (18, 24, 30), (20, 21, 29), (21, 28, 35), (24, 32, 40), (27, 36, 45)]

# %%
# List comprehension을 활용하여 만들어주세요.
[(x,y,z) for x in range(1, 50) for y in range(x+1, 50) for z in range(y+1, 50) if x**2 + y**2 == z**2]
# Out:
# [(3, 4, 5),
#  (5, 12, 13),
#  (6, 8, 10),
#  (7, 24, 25),
#  (8, 15, 17),
#  (9, 12, 15),
#  (9, 40, 41),
#  (10, 24, 26),
#  (12, 16, 20),
#  (12, 35, 37),
#  (15, 20, 25),
#  (15, 36, 39),
#  (16, 30, 34),
#  (18, 24, 30),
#  (20, 21, 29),
#  (21, 28, 35),
#  (24, 32, 40),
#  (27, 36, 45)]

# %% [markdown]
# ### 모음 제거하기
#
# > 다음의 문장에서 모음(a, e, i, o, u)를 모두 제거하시오.
#
# 1. list comprehension만 사용해보세요.
#
# ```
#     words = 'Life is too short, you need python!'
#
#     예시출력)
#     Lf s t shrt, y nd pythn!
# ```

# %%
words = 'Life is too short, you need python!'
non_moum = ''

for i in words:
    if i not in 'aeiou':
        non_moum += i
print(non_moum)
# Out:
# Lf s t shrt, y nd pythn!

# %%
# List comprehension을 활용하여 만들어주세요.
aa = ''.join([i for i in words if i not in 'aeiou'])
print(aa)
# Out:
# Lf s t shrt, y nd pythn!

# %% [markdown]
# # 딕셔너리 메소드 활용

# %% [markdown]
# ## 추가 및 삭제
#
# ### `.pop(key[, default])`
#
# key가 딕셔너리에 있으면 제거하고 그 값을 돌려줍니다. 그렇지 않으면 default를 반환합니다.
#
# default가 없는 상태에서 딕셔너리에 없으면 KeyError가 발생합니다.

# %%
# pop을 사용해봅시다.
my_dict = {'apple': '사과', 'banana': '바나나'}

# %%
my_dict.pop('melon', True)
# Out:
# True

# %%
# 딕셔너리에 없으면 에러가 발생합니다
my_dict.pop('apple')
# Out:
# '사과'

# %%
print(my_dict)
# Out:
# {'banana': '바나나'}

# %%
# 두번째 인자로 default를 설정할 수 있습니다
my_dict.pop('melon', 0)
# Out:
# 0

# %%
print(my_dict)
# Out:
# {'banana': '바나나'}

# %% [markdown]
# ### `.update()`
#
# 값을 제공하는 key, value로 덮어씁니다.

# %%
# update를 사용해봅시다.
my_dict = {'apple': '사과', 'banana': '바나나', 'melon': '멜론'}

# %%
my_dict.update({'apple' : '노트북'})
print(my_dict)
# Out:
# {'apple': '노트북', 'banana': '바나나', 'melon': '멜론'}

# %%
my_dict.update(apple = '사과야') # update() -> 함수 키워드 인자는 변수에 값을 넣는다는 의미
print(my_dict)
# Out:
# {'apple': '사과야', 'banana': '바나나', 'melon': '멜론'}

# %%
my_dict.update({'banana' : '바나나야'})

# %%
print(my_dict)
# Out:
# {'apple': '사과야', 'banana': '바나나야', 'melon': '멜론'}

# %%
my_dict.update(grape='포도')

# %%
print(my_dict)
# Out:
# {'apple': '사과야', 'banana': '바나나야', 'melon': '멜론', 'grape': '포도'}

# %% [markdown]
# ### `.get(key[, default])`
#
# key를 통해 value를 가져옵니다.
#
# 절대로 KeyError가 발생하지 않습니다. default는 기본적으로 None입니다.

# %%
# get을 사용해봅시다.
my_dict = {'apple': '사과', 'banana': '바나나', 'melon': '멜론'}
# my_dict['pineapple']
my_dict.get('apple', False)
# Out:
# '사과'

# %%
print(my_dict.get('pineapple'))
# Out:
# None

# %%
my_dict.get('pineapple', False)
# Out:
# False

# %% [markdown]
# ## dictionary comprehension
#
# dictionary도 comprehension을 활용하여 만들 수 있습니다.

# %%
# dictionary comprehension
[x**3 for x in range(1,5)]
# Out:
# [1, 8, 27, 64]

# %%
{x:x**3 for x in range(1,5)}
# Out:
# {1: 1, 2: 8, 3: 27, 4: 64}

# %%
{char: 0 for char in range(5)}
# Out:
# {0: 0, 1: 0, 2: 0, 3: 0, 4: 0}

# %%
# 딕셔너리로 활용하여 만든다
{x: x**3 for x in range(1,5)}
# Out:
# {1: 1, 2: 8, 3: 27, 4: 64}

# %%
# 위에 코드와 동일
result = {}
for x in range(1,5):
    result[x] = x**3
print(result)
# Out:
# {1: 1, 2: 8, 3: 27, 4: 64}

# %%
# 0으로 초기화한 딕셔너리 만든다
{char: 0 for char in 'abcedf'}
# Out:
# {'a': 0, 'b': 0, 'c': 0, 'e': 0, 'd': 0, 'f': 0}

# %%
result = {}
for x in 'abcdef':
    result[x] = 0
print(result)
# Out:
# {'a': 0, 'b': 0, 'c': 0, 'd': 0, 'e': 0, 'f': 0}

# %% [markdown]
# ### dictionary comprehension 사용해보기

# %%
dusts = {'서울': 72, '대전': 82, '구미': 29, '광주': 45, '중국': 200}

# %%
# 미세먼지 농도가 80 초과 지역만 뽑아 봅시다.
# 예) {'대전': 82, '중국': 200}
{dust: val for dust, val in dusts.items() if val > 80}
# 미세먼지 농도가 80초과는 나쁨 80이하는 보통으로 하는 value를 가지도록 바꿔봅시다.
{dust: '나쁨 'if val > 80 else '보통' for dust, val in dusts.items()}
{dust: '매우 나쁨' if val > 80 else '나쁨' if val > 70 else '보통' if val > 40 else '좋음' for dust, val in dusts.items()}
# Out:
# {'서울': '나쁨', '대전': '매우 나쁨', '구미': '좋음', '광주': '보통', '중국': '매우 나쁨'}

# %%
# 미세먼지 농도가 80 초과 지역만 뽑아 봅시다.
# 예) {'대전': 82, '중국': 200}
dust_80 = {}
{dust: val for dust, val in dusts.items() if val > 80}
# Out:
# {'대전': 82, '중국': 200}

# %%
{city: dusts[city] for city in dusts if dusts[city] > 80}
# Out:
# {'대전': 82, '중국': 200}

# %%
# 미세먼지 농도가 80초과는 나쁨 80이하는 보통으로 하는 value를 가지도록 바꿔봅시다.
dust_80 = {}
{dust: '나쁨' if val > 80 else '보통' for dust, val in dusts.items()}
# Out:
# {'서울': '보통', '대전': '나쁨', '구미': '보통', '광주': '보통', '중국': '나쁨'}

# %%
# elif 도 사용할 수 있습니다.
{key: '매우나쁨' if value > 150 else '나쁨' if value > 80 else '보통' if value > 30 else '좋음' for key, value in dusts.items()}
# Out:
# {'서울': '보통', '대전': '나쁨', '구미': '좋음', '광주': '보통', '중국': '매우나쁨'}

# %% [markdown]
# # 세트 메소드 활용

# %% [markdown]
# ## 추가 및 삭제
#
# ### `.add(elem)`
# elem을 세트에 추가합니다.

# %%
# add를 사용해봅시다.
a = {"사과", "바나나", "수박"}

# %%
a.add('파인애플')
print(a)
# set은 중복된 값을 가질 수 없다!!
# add를 반복해 같은 값을 넣어도 동일
# Out:
# {'수박', '바나나', '사과', '파인애플'}

# %% [markdown]
# ### `update(*others)`
#
# 여러가지의 값을 추가합니다.
#
# 여기서 반드시 iterable한 값을 넣어야합니다.

# %%
# update를 사용해봅시다.
a = {"사과", "바나나", "수박"}

# %%
# 이렇게 보내면 안돼
a.update('토마토', '딸기')
print(a)
# Out:
# {'딸', '수박', '기', '마', '바나나', '토'}

# %%
# 업데이트시 꼭 튜플로 묶어서 보내야한다.
a.update(('토마토', '딸기'))
print(a)
# Out:
# {'사과', '토마토', '딸기', '수박', '바나나'}

# %%
# 따로 나눠서 보내고 싶으면 이런식으로 보내야한다.
a.update(('토마토', ), ('딸기', ))
print(a)
# Out:
# {'사과', '토마토', '딸기', '수박', '바나나'}

# %% [markdown]
# ### `.remove(elem)`
#
# elem을 세트에서 삭제하고, 없으면 KeyError가 발생합니다.

# %%
# remove를 사용해봅시다.
a = {"사과", "바나나", "수박"}
a.remove('사과')
print(a)
# Out:
# {'수박', '바나나'}

# %%
a.remove('파인애플')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-d3d913a349ef> in <module>
# ----> 1 a.remove('파인애플')
#
# KeyError: '파인애플'

# %% [markdown]
# ### `discard(elem)`
# x를 세트에서 삭제하고 없어도 에러가 발생하지 않습니다.

# %%
# discard를 사용해봅시다.
a = {"사과", "바나나", "수박"}
a.discard('파인애플') # 없으면 아무짓도 하지 않고 오류 발생 X

# %% [markdown]
# ### `pop()`
#
# 임의의 원소를 제거해 반환합니다.

# %%
# pop을 사용해봅시다.
a = {"사과", "바나나", "수박", "아보카도"}

# %% [markdown]
# ##  `map()`, `zip()`, `filter()`

# %% [markdown]
# ### `map(function, iterable)`
#
# * Iterable의 모든 원소에 function을 적용한 후 그 결과를 돌려줍니다.
#
# * 대표적으로 iterable한 타입 - list, dict, set, str, bytes, tuple, range
#
# * return은 map_object 형태로 됩니다.

# %%
a = [1, 2, 3]
# 위의 코드를 문자열 '123'으로 만들어봅시다.

# %%
# list comprehension
[str(elem) for elem in a]
# Out:
# ['1', '2', '3']

# %%
''.join([str(elem) for elem in a])
# Out:
# '123'

# %%
map(str,a)

# %%
''.join(map(str,a))
# Out:
# '123'

# %%
# Out:
# ['123']

# %%
a = ['1', '2', '3']
# 위의 코드를 [1, 2, 3]으로 만들어봅시다.

# %%
# list comprehension
b, c, d = map(str,a)
print(b, c, d)
# Out:
# 123

# %%
numbers = list(map(int,a))

# %%
[int(elem) for elem in a]
# Out:
# [1, 2, 3]

# %% [markdown]
# * function은 사용자 정의 함수도 가능합니다.

# %%
# 세제곱의 결과를 나타내는 함수
def cube(n):
    return n**3

# %%
list(map(cube, range(4)))
# Out:
# [0, 1, 8, 27]

# %%
[cube(elem) for elem in numbers]
# Out:
# [1, 8, 27]

# %%
# 함수를 함수의 인자로 넘겨줄 수 있다.
list(map(cube, numbers))
# Out:
# [1, 8, 27]

# %%
# 함수를 변수에 저장할 수 있다.
my_sum = sum

# %%
my_sum([1, 2, 3])
# Out:
# 6

# %% [markdown]
# ### `zip(*iterables)`
#
# * 복수 iterable한 것들을 모아준다.
#
# * 결과는 튜플의 모음으로 구성된 zip object를 반환한다.

# %%
# 예시를 봅시다.
girls = ['jane', 'iu', 'mary']
boys = ['justin', 'david', 'kim']

# %%
# 매우 복잡
result = []
for idx_girl, girl in enumerate(girls):
    for idx_boy, boy in enumerate(boys):
        if idx_girl == idx_boy:
            result.append((girl, boy))
print(result)
# Out:
# [('jane', 'justin'), ('iu', 'david'), ('mary', 'kim')]

# %%
result = []
for girl, boy in zip(girls, boys):
    result.append((girl, boy))
print(result)
# Out:
# [('jane', 'justin'), ('iu', 'david'), ('mary', 'kim')]

# %%
list(zip(girls, boys)) # 튜플이 묶여있는 리스트 형태
# Out:
# [('jane', 'justin'), ('iu', 'david'), ('mary', 'kim')]

# %%
dusts.items() # 이것 또한 마찬가지로 튜플이 묶여있는 리스트 형태
# Out:
# dict_items([('서울', 72), ('대전', 82), ('구미', 29), ('광주', 45), ('중국', 200)])

# %%
# for문으로 한 명씩 순서대로 매칭시켜봅시다.
# 예) {'jane': 'justin', 'iu': 'david', 'mary': 'kim'}
dict(zip(girls, boys))
# Out:
# {'jane': 'justin', 'iu': 'david', 'mary': 'kim'}

# %%
{girl: boy for girl, boy in zip(girls, boys)}
# Out:
# {'jane': 'justin', 'iu': 'david', 'mary': 'kim'}

# %% [markdown]
# * 아래와 같이 사용가능하다.

# %%
a = '123'
b = '567'

for digit_a, digit_b in zip(a, b):
    print(digit_a, digit_b)
# Out:
# 1 5
# 2 6
# 3 7

# %% [markdown]
# * zip은 반드시 길이가 같을 때 사용해야한다. 가장 짧은 것을 기준으로 구성한다.

# %%
# 짧은것을 기준으로 맞춰진다.
num1 = [1, 2, 3]
num2 = ['1', '2']
list(zip(num1, num2))
# Out:
# [(1, '1'), (2, '2')]

# %% [markdown]
# * 길이가 긴 것을 맞춰서 할 수도 있지만, 사용할 일이 없다.

# %%
from itertools import zip_longest
list(zip_longest(num1, num2, fillvalue=0))
# Out:
# [(1, '1'), (2, '2'), (3, 0)]

# %% [markdown]
# ### `filter(function, iterable)`
#
# * iterable에서 function의 반환된 결과가 참인 것들만 구성하여 반환한다.

# %%
# 짝수인지 판단하는 함수를 작성해봅시다.
# 필터는 참 혹은 거짓인 것만 걸러준다!

# %%
def even(n):
    return not n%2

# %%
list(filter(even, range(1,10)))
# Out:
# [2, 4, 6, 8]

# %%
list(filter(even, range(1,10)))
# Out:
# [2, 4, 6, 8]

# %%
# 다음의 list comprehension과 동일하다.
[num for num in range(1,10) if even(num)]
# Out:
# [2, 4, 6, 8]
